# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import io
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c672e2ec-9189-4592-ad47-42d7535d6f2b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c672e2ec-9189-4592-ad47-42d7535d6f2b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hours.csv to hours (3).csv

# %%
dataset = pd.read_csv(io.BytesIO(uploaded['hours.csv']))
X=dataset.iloc[:,:-1].values
y=dataset.iloc[:,1].values

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X,y)
print("Accuracy : "),regressor.score(X,y)*100
# Out:
# Accuracy :
# (None, 93.62578423743744)

# %%
hours=int(input("Enter hours:"))
# Out:
# Enter hours:10

# %%
eq=regressor.coef_*hours+regressor.intercept_
#print 'y=%f*%f+%f' %(regressor.coef_,hours,regressor.intercept_)
print(regressor.coef_,end=" ") 
print("*",end=" ") 
print(hours,end=" ") 
print("+",end=" ") 
print(regressor.intercept_)
print("Risk factor:",eq[0])
# Out:
# [7.65085854] * 10 + 8.259198691741645
# Risk factor: 84.76778413736714

# %%
plt.plot(X,y,'o')
plt.plot(X,regressor.predict(X))
plt.show()
